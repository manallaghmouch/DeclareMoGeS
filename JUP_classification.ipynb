# %% [markdown]
# 0 Define input parameters

# %%
path_normative_model = "model1_1.decl"
path_auditor_model = "model1_2.decl"
path_real_model = "model1_3.decl"

# %% [markdown]
# 1 Log generation

# %%
# Create synthetic event log 
import os
from Declare4Py.ProcessModels.DeclareModel import DeclareModel
from Declare4Py.ProcessMiningTasks.LogGenerator.ASP.ASPLogGenerator import AspGenerator

# %%
# import declarative model
declare_model: DeclareModel = DeclareModel().parse_from_file(os.path.join(path_real_model))

# %%
# set input parameters log generator
num_of_cases = 10000
(num_min_events, num_max_events) = (8,15)
verbose = True

# %%
# run generator
asp_gen: AspGenerator = AspGenerator(declare_model, num_of_cases, num_min_events, num_max_events, verbose=verbose)
asp_gen.run()
# Out:
# DEBUG:ASP generator:Distribution for traces UNIFORM
# DEBUG:ASP generator:traces: 10000, events can have a trace min(8) max(15)
# DEBUG:Distribution:Distribution() UNIFORM min_mu: 8 max_sigma: 15 num_traces: 10000 custom_prob: None
# DEBUG:Distribution:Calculating Uniform Distribution
# DEBUG:Distribution:Generating Uniform Probabilities since either distribution is uniform or custom probabilities are None
# DEBUG:Distribution:Probabilities sum is 1
# DEBUG:Distribution:Distribution result: [10  8  9 ... 11 14 10]
# DEBUG:ASP generator:Prepared distribution of 10000 positive traces with distribution: Counter({14: 1318, 10: 1278, 12: 1260, 11: 1243, 15: 1238, 13: 1226, 9: 1225, 8: 1212})
# DEBUG:ASP generator:Prepared distribution of 0 negative traces with distribution: Counter()
# DEBUG:ASP generator:Generating positive Traces
# DEBUG:ASP generator:Translate declare model to ASP
# DEBUG:ASP generator:Declare model translated to ASP. Total Facts 10
# DEBUG:ASP generator:ASP encoding generated
# DEBUG:ASP generator:Total trace to generate and events: Traces:1278, Events: 10, Seed:262788747
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_2,4), trace(evt_val_2,5), trace(evt_val_2,6), trace(evt_val_2,7), trace(evt_val_2,8), trace(evt_val_2,9), trace(evt_val_3,10)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,4), trace(evt_val_0,5), trace(evt_val_2,3), trace(evt_val_2,6), trace(evt_val_3,7), trace(evt_val_3,10), trace(evt_val_5,9), trace(evt_val_7,1), trace(evt_val_9,2), trace(evt_val_9,8)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,7), trace(evt_val_1,6), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_2,4), trace(evt_val_2,8), trace(evt_val_3,10), trace(evt_val_5,9), trace(evt_val_7,1), trace(evt_val_9,5)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,4), trace(evt_val_1,6), trace(evt_val_2,2), trace(evt_val_2,5), trace(evt_val_3,10), trace(evt_val_4,7), trace(evt_val_5,9), trace(evt_val_7,1), trace(evt_val_9,3), trace(evt_val_9,8)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,4), trace(evt_val_0,6), trace(evt_val_1,7), trace(evt_val_1,8), trace(evt_val_2,5), trace(evt_val_3,10), trace(evt_val_5,9), trace(evt_val_6,3), trace(evt_val_7,2), trace(evt_val_9,1)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,6), trace(evt_val_0,7), trace(evt_val_1,3), trace(evt_val_2,5), trace(evt_val_3,10), trace(evt_val_5,9), trace(evt_val_6,4), trace(evt_val_7,2), trace(evt_val_9,8)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,3), trace(evt_val_3,2), trace(evt_val_3,5), trace(evt_val_3,6), trace(evt_val_3,7), trace(evt_val_3,8), trace(evt_val_3,10), trace(evt_val_5,9), trace(evt_val_7,1), trace(evt_val_9,4)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_3,3), trace(evt_val_3,8), trace(evt_val_3,10), trace(evt_val_5,4), trace(evt_val_5,6), trace(evt_val_5,9), trace(evt_val_7,1), trace(evt_val_7,5), trace(evt_val_9,2), trace(evt_val_9,7)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,3), trace(evt_val_1,6), trace(evt_val_1,9), trace(evt_val_3,2), trace(evt_val_3,4), trace(evt_val_3,8), trace(evt_val_3,10), trace(evt_val_5,7), trace(evt_val_7,1), trace(evt_val_9,5)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,4), trace(evt_val_0,6), trace(evt_val_2,5), trace(evt_val_3,7), trace(evt_val_3,10), trace(evt_val_5,9), trace(evt_val_6,3), trace(evt_val_7,2), trace(evt_val_9,1), trace(evt_val_9,8)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,7), trace(evt_val_2,3), trace(evt_val_3,4), trace(evt_val_3,5), trace(evt_val_3,6), trace(evt_val_3,8), trace(evt_val_3,10), trace(evt_val_5,9), trace(evt_val_7,1), trace(evt_val_9,2)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,2), trace(evt_val_3,9), trace(evt_val_3,10), trace(evt_val_4,3), trace(evt_val_9,1), trace(evt_val_9,4), trace(evt_val_9,5), trace(evt_val_9,6), trace(evt_val_9,7), trace(evt_val_9,8)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,4), trace(evt_val_1,9), trace(evt_val_3,5), trace(evt_val_3,6), trace(evt_val_3,7), trace(evt_val_3,8), trace(evt_val_3,10), trace(evt_val_5,2), trace(evt_val_7,3), trace(evt_val_9,1)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,6), trace(evt_val_1,3), trace(evt_val_1,5), trace(evt_val_3,4), trace(evt_val_3,7), trace(evt_val_3,9), trace(evt_val_3,10), trace(evt_val_5,8), trace(evt_val_7,1), trace(evt_val_9,2)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,3), trace(evt_val_3,2), trace(evt_val_3,4), trace(evt_val_3,5), trace(evt_val_3,6), trace(evt_val_3,7), trace(evt_val_3,10), trace(evt_val_9,1), trace(evt_val_9,8), trace(evt_val_9,9)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_3,4), trace(evt_val_3,8), trace(evt_val_3,9), trace(evt_val_3,10), trace(evt_val_5,6), trace(evt_val_7,1), trace(evt_val_7,3), trace(evt_val_7,5), trace(evt_val_9,2), trace(evt_val_9,7)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_3,3), trace(evt_val_3,5), trace(evt_val_3,6), trace(evt_val_3,7), trace(evt_val_3,8), trace(evt_val_3,10), trace(evt_val_5,9), trace(evt_val_7,4), trace(evt_val_9,2)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_1,5), trace(evt_val_2,9), trace(evt_val_3,4), trace(evt_val_3,7), trace(evt_val_3,8), trace(evt_val_3,10), trace(evt_val_5,6), trace(evt_val_6,3), trace(evt_val_7,2), trace(evt_val_9,1)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_1,4), trace(evt_val_3,3), trace(evt_val_3,5), trace(evt_val_3,6), trace(evt_val_3,7), trace(evt_val_3,8), trace(evt_val_3,10), trace(evt_val_5,9), trace(evt_val_7,1), trace(evt_val_9,2)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,2), trace(evt_val_3,9), trace(evt_val_3,10), trace(evt_val_4,3), trace(evt_val_5,8), trace(evt_val_9,1), trace(evt_val_9,4), trace(evt_val_9,5), trace(evt_val_9,6), trace(evt_val_9,7)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,5), trace(evt_val_0,7), trace(evt_val_2,4), trace(evt_val_2,6), trace(evt_val_3,2), trace(evt_val_3,10), trace(evt_val_5,9), trace(evt_val_6,1), trace(evt_val_7,3), trace(evt_val_9,8)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,2), trace(evt_val_3,4), trace(evt_val_3,5), trace(evt_val_3,6), trace(evt_val_3,7), trace(evt_val_3,8), trace(evt_val_3,10), trace(evt_val_5,9), trace(evt_val_7,3), trace(evt_val_9,1)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_2,1), trace(evt_val_2,3), trace(evt_val_3,2), trace(evt_val_3,5), trace(evt_val_3,6), trace(evt_val_3,7), trace(evt_val_3,10), trace(evt_val_9,4), trace(evt_val_9,8), trace(evt_val_9,9)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_2,4), trace(evt_val_3,8), trace(evt_val_3,9), trace(evt_val_3,10), trace(evt_val_5,2), trace(evt_val_5,6), trace(evt_val_7,3), trace(evt_val_7,5), trace(evt_val_9,1), trace(evt_val_9,7)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,8), trace(evt_val_3,2), trace(evt_val_3,3), trace(evt_val_3,5), trace(evt_val_3,6), trace(evt_val_3,7), trace(evt_val_3,10), trace(evt_val_5,9), trace(evt_val_7,4), trace(evt_val_9,1)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_1,5), trace(evt_val_2,9), trace(evt_val_3,4), trace(evt_val_3,6), trace(evt_val_3,7), trace(evt_val_3,10), trace(evt_val_5,8), trace(evt_val_6,3), trace(evt_val_7,1), trace(evt_val_9,2)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,7), trace(evt_val_2,8), trace(evt_val_3,3), trace(evt_val_3,4), trace(evt_val_3,5), trace(evt_val_3,6), trace(evt_val_3,10), trace(evt_val_5,9), trace(evt_val_7,1), trace(evt_val_9,2)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,2), trace(evt_val_3,7), trace(evt_val_3,9), trace(evt_val_3,10), trace(evt_val_4,3), trace(evt_val_5,8), trace(evt_val_9,1), trace(evt_val_9,4), trace(evt_val_9,5), trace(evt_val_9,6)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_1,5), trace(evt_val_2,4), trace(evt_val_3,2), trace(evt_val_3,6), trace(evt_val_3,8), trace(evt_val_3,9), trace(evt_val_3,10), trace(evt_val_5,7), trace(evt_val_7,3), trace(evt_val_9,1)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,2), trace(evt_val_1,3), trace(evt_val_3,4), trace(evt_val_3,6), trace(evt_val_3,7), trace(evt_val_3,9), trace(evt_val_3,10), trace(evt_val_5,8), trace(evt_val_7,1), trace(evt_val_9,5)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_3,2), trace(evt_val_3,5), trace(evt_val_3,6), trace(evt_val_3,10), trace(evt_val_5,4), trace(evt_val_5,7), trace(evt_val_5,8), trace(evt_val_7,1), trace(evt_val_9,3), trace(evt_val_9,9)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_3,2), trace(evt_val_3,4), trace(evt_val_3,5), trace(evt_val_3,10), trace(evt_val_5,7), trace(evt_val_5,8), trace(evt_val_6,3), trace(evt_val_7,1), trace(evt_val_9,6), trace(evt_val_9,9)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_2,9), trace(evt_val_3,5), trace(evt_val_3,6), trace(evt_val_3,7), trace(evt_val_3,10), trace(evt_val_5,8), trace(evt_val_7,3), trace(evt_val_7,4), trace(evt_val_8,1), trace(evt_val_9,2)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_2,9), trace(evt_val_3,4), trace(evt_val_3,5), trace(evt_val_3,6), trace(evt_val_3,7), trace(evt_val_3,10), trace(evt_val_5,8), trace(evt_val_6,3), trace(evt_val_7,1), trace(evt_val_9,2)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,7), trace(evt_val_3,5), trace(evt_val_3,6), trace(evt_val_3,8), trace(evt_val_3,9), trace(evt_val_3,10), trace(evt_val_5,4), trace(evt_val_6,3), trace(evt_val_7,1), trace(evt_val_9,2)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,2), trace(evt_val_3,9), trace(evt_val_3,10), trace(evt_val_4,3), trace(evt_val_5,7), trace(evt_val_7,8), trace(evt_val_9,1), trace(evt_val_9,4), trace(evt_val_9,5), trace(evt_val_9,6)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,5), trace(evt_val_3,2), trace(evt_val_3,6), trace(evt_val_3,7), trace(evt_val_3,8), trace(evt_val_3,10), trace(evt_val_5,9), trace(evt_val_6,1), trace(evt_val_7,3), trace(evt_val_9,4)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_1,3), trace(evt_val_1,6), trace(evt_val_3,2), trace(evt_val_3,4), trace(evt_val_3,5), trace(evt_val_3,7), trace(evt_val_3,10), trace(evt_val_5,9), trace(evt_val_7,1), trace(evt_val_9,8)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,8), trace(evt_val_2,3), trace(evt_val_2,4), trace(evt_val_3,5), trace(evt_val_3,10), trace(evt_val_4,9), trace(evt_val_5,2), trace(evt_val_5,6), trace(evt_val_9,1), trace(evt_val_9,7)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_3,4), trace(evt_val_3,6), trace(evt_val_3,10), trace(evt_val_5,7), trace(evt_val_5,8), trace(evt_val_5,9), trace(evt_val_7,1), trace(evt_val_7,3), trace(evt_val_7,5), trace(evt_val_9,2)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_2,7), trace(evt_val_3,5), trace(evt_val_3,6), trace(evt_val_3,8), trace(evt_val_3,10), trace(evt_val_5,9), trace(evt_val_6,1), trace(evt_val_7,3), trace(evt_val_7,4), trace(evt_val_9,2)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_3,4), trace(evt_val_3,5), trace(evt_val_3,6), trace(evt_val_3,7), trace(evt_val_3,9), trace(evt_val_3,10), trace(evt_val_5,8), trace(evt_val_6,3), trace(evt_val_7,1), trace(evt_val_9,2)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,7), trace(evt_val_0,8), trace(evt_val_1,5), trace(evt_val_2,6), trace(evt_val_3,3), trace(evt_val_3,4), trace(evt_val_3,10), trace(evt_val_5,9), trace(evt_val_7,1), trace(evt_val_9,2)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,2), trace(evt_val_3,9), trace(evt_val_3,10), trace(evt_val_4,3), trace(evt_val_5,4), trace(evt_val_9,1), trace(evt_val_9,5), trace(evt_val_9,6), trace(evt_val_9,7), trace(evt_val_9,8)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_2,1), trace(evt_val_3,2), trace(evt_val_3,3), trace(evt_val_3,5), trace(evt_val_3,6), trace(evt_val_3,7), trace(evt_val_3,9), trace(evt_val_3,10), trace(evt_val_5,8), trace(evt_val_9,4)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,2), trace(evt_val_1,3), trace(evt_val_2,7), trace(evt_val_3,4), trace(evt_val_3,8), trace(evt_val_3,9), trace(evt_val_3,10), trace(evt_val_5,6), trace(evt_val_7,1), trace(evt_val_9,5)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,4), trace(evt_val_3,5), trace(evt_val_3,8), trace(evt_val_3,10), trace(evt_val_4,9), trace(evt_val_5,2), trace(evt_val_5,6), trace(evt_val_7,3), trace(evt_val_9,1), trace(evt_val_9,7)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_1,2), trace(evt_val_3,6), trace(evt_val_3,10), trace(evt_val_5,4), trace(evt_val_5,7), trace(evt_val_5,8), trace(evt_val_5,9), trace(evt_val_7,1), trace(evt_val_7,5), trace(evt_val_9,3)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,2), trace(evt_val_0,8), trace(evt_val_3,5), trace(evt_val_3,7), trace(evt_val_3,10), trace(evt_val_5,9), trace(evt_val_6,6), trace(evt_val_7,3), trace(evt_val_7,4), trace(evt_val_9,1)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_3,2), trace(evt_val_3,4), trace(evt_val_3,6), trace(evt_val_3,7), trace(evt_val_3,9), trace(evt_val_3,10), trace(evt_val_5,8), trace(evt_val_6,3), trace(evt_val_7,1), trace(evt_val_9,5)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,7), trace(evt_val_2,4), trace(evt_val_2,6), trace(evt_val_3,3), trace(evt_val_3,5), trace(evt_val_3,8), trace(evt_val_3,10), trace(evt_val_5,9), trace(evt_val_7,1), trace(evt_val_9,2)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,4), trace(evt_val_3,3), trace(evt_val_3,10), trace(evt_val_5,9), trace(evt_val_7,1), trace(evt_val_9,2), trace(evt_val_9,5), trace(evt_val_9,6), trace(evt_val_9,7), trace(evt_val_9,8)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_3,5), trace(evt_val_3,6), trace(evt_val_3,7), trace(evt_val_3,8), trace(evt_val_3,10), trace(evt_val_5,2), trace(evt_val_7,3), trace(evt_val_7,4), trace(evt_val_7,9), trace(evt_val_9,1)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,2), trace(evt_val_0,9), trace(evt_val_1,3), trace(evt_val_3,4), trace(evt_val_3,6), trace(evt_val_3,8), trace(evt_val_3,10), trace(evt_val_5,7), trace(evt_val_7,1), trace(evt_val_9,5)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,5), trace(evt_val_3,4), trace(evt_val_3,7), trace(evt_val_3,8), trace(evt_val_3,10), trace(evt_val_4,9), trace(evt_val_5,2), trace(evt_val_5,6), trace(evt_val_7,3), trace(evt_val_9,1)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_3,3), trace(evt_val_3,6), trace(evt_val_3,10), trace(evt_val_5,5), trace(evt_val_5,7), trace(evt_val_5,8), trace(evt_val_5,9), trace(evt_val_7,1), trace(evt_val_9,2), trace(evt_val_9,4)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_3,5), trace(evt_val_3,6), trace(evt_val_3,7), trace(evt_val_3,10), trace(evt_val_5,8), trace(evt_val_5,9), trace(evt_val_7,3), trace(evt_val_7,4), trace(evt_val_9,1), trace(evt_val_9,2)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,9), trace(evt_val_3,2), trace(evt_val_3,4), trace(evt_val_3,6), trace(evt_val_3,7), trace(evt_val_3,10), trace(evt_val_5,8), trace(evt_val_6,3), trace(evt_val_7,1), trace(evt_val_9,5)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_3,3), trace(evt_val_3,4), trace(evt_val_3,5), trace(evt_val_3,6), trace(evt_val_3,8), trace(evt_val_3,9), trace(evt_val_3,10), trace(evt_val_5,7), trace(evt_val_7,1), trace(evt_val_9,2)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,2), trace(evt_val_3,9), trace(evt_val_3,10), trace(evt_val_4,3), trace(evt_val_5,4), trace(evt_val_5,7), trace(evt_val_9,1), trace(evt_val_9,5), trace(evt_val_9,6), trace(evt_val_9,8)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,9), trace(evt_val_2,8), trace(evt_val_3,5), trace(evt_val_3,6), trace(evt_val_3,7), trace(evt_val_3,10), trace(evt_val_5,2), trace(evt_val_7,3), trace(evt_val_7,4), trace(evt_val_9,1)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_1,3), trace(evt_val_2,6), trace(evt_val_2,9), trace(evt_val_3,4), trace(evt_val_3,5), trace(evt_val_3,7), trace(evt_val_3,10), trace(evt_val_5,8), trace(evt_val_7,1), trace(evt_val_9,2)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,4), trace(evt_val_3,8), trace(evt_val_3,10), trace(evt_val_4,9), trace(evt_val_5,2), trace(evt_val_5,6), trace(evt_val_7,3), trace(evt_val_7,5), trace(evt_val_9,1), trace(evt_val_9,7)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_3,6), trace(evt_val_3,7), trace(evt_val_3,10), trace(evt_val_5,8), trace(evt_val_5,9), trace(evt_val_7,1), trace(evt_val_7,3), trace(evt_val_9,2), trace(evt_val_9,4), trace(evt_val_9,5)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_2,6), trace(evt_val_3,5), trace(evt_val_3,7), trace(evt_val_3,8), trace(evt_val_3,10), trace(evt_val_5,9), trace(evt_val_7,3), trace(evt_val_7,4), trace(evt_val_9,1), trace(evt_val_9,2)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_3,2), trace(evt_val_3,4), trace(evt_val_3,6), trace(evt_val_3,7), trace(evt_val_3,10), trace(evt_val_5,9), trace(evt_val_6,3), trace(evt_val_7,1), trace(evt_val_9,5), trace(evt_val_9,8)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,4), trace(evt_val_2,6), trace(evt_val_3,3), trace(evt_val_3,5), trace(evt_val_3,8), trace(evt_val_3,9), trace(evt_val_3,10), trace(evt_val_5,7), trace(evt_val_7,1), trace(evt_val_9,2)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_1,2), trace(evt_val_1,3), trace(evt_val_2,7), trace(evt_val_3,10), trace(evt_val_5,9), trace(evt_val_7,1), trace(evt_val_9,4), trace(evt_val_9,5), trace(evt_val_9,6), trace(evt_val_9,8)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,7), trace(evt_val_3,2), trace(evt_val_3,5), trace(evt_val_3,6), trace(evt_val_3,8), trace(evt_val_3,10), trace(evt_val_5,9), trace(evt_val_7,3), trace(evt_val_7,4), trace(evt_val_9,1)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,2), trace(evt_val_0,6), trace(evt_val_0,9), trace(evt_val_1,3), trace(evt_val_3,5), trace(evt_val_3,10), trace(evt_val_5,7), trace(evt_val_5,8), trace(evt_val_7,1), trace(evt_val_9,4)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,2), trace(evt_val_3,8), trace(evt_val_3,10), trace(evt_val_4,9), trace(evt_val_5,4), trace(evt_val_5,6), trace(evt_val_7,3), trace(evt_val_7,5), trace(evt_val_9,1), trace(evt_val_9,7)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_3,10), trace(evt_val_5,3), trace(evt_val_5,7), trace(evt_val_5,8), trace(evt_val_5,9), trace(evt_val_7,1), trace(evt_val_7,6), trace(evt_val_9,2), trace(evt_val_9,4), trace(evt_val_9,5)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_1,8), trace(evt_val_3,5), trace(evt_val_3,7), trace(evt_val_3,10), trace(evt_val_5,9), trace(evt_val_6,6), trace(evt_val_7,3), trace(evt_val_7,4), trace(evt_val_9,1), trace(evt_val_9,2)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_1,2), trace(evt_val_3,3), trace(evt_val_3,4), trace(evt_val_3,7), trace(evt_val_3,9), trace(evt_val_3,10), trace(evt_val_5,6), trace(evt_val_7,1), trace(evt_val_9,5), trace(evt_val_9,8)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,6), trace(evt_val_3,3), trace(evt_val_3,5), trace(evt_val_3,7), trace(evt_val_3,8), trace(evt_val_3,9), trace(evt_val_3,10), trace(evt_val_5,4), trace(evt_val_9,2)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,2), trace(evt_val_0,4), trace(evt_val_3,9), trace(evt_val_3,10), trace(evt_val_4,3), trace(evt_val_9,1), trace(evt_val_9,5), trace(evt_val_9,6), trace(evt_val_9,7), trace(evt_val_9,8)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,2), trace(evt_val_3,5), trace(evt_val_3,6), trace(evt_val_3,8), trace(evt_val_3,10), trace(evt_val_5,7), trace(evt_val_7,3), trace(evt_val_7,4), trace(evt_val_9,1), trace(evt_val_9,9)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_1,3), trace(evt_val_1,6), trace(evt_val_1,9), trace(evt_val_3,4), trace(evt_val_3,5), trace(evt_val_3,7), trace(evt_val_3,10), trace(evt_val_5,8), trace(evt_val_7,1), trace(evt_val_9,2)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_3,4), trace(evt_val_3,8), trace(evt_val_3,10), trace(evt_val_5,2), trace(evt_val_5,6), trace(evt_val_5,9), trace(evt_val_7,3), trace(evt_val_7,5), trace(evt_val_9,1), trace(evt_val_9,7)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_3,6), trace(evt_val_3,10), trace(evt_val_5,3), trace(evt_val_5,7), trace(evt_val_5,8), trace(evt_val_5,9), trace(evt_val_7,4), trace(evt_val_9,1), trace(evt_val_9,2), trace(evt_val_9,5)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_1,8), trace(evt_val_3,2), trace(evt_val_3,5), trace(evt_val_3,6), trace(evt_val_3,7), trace(evt_val_3,10), trace(evt_val_5,9), trace(evt_val_7,3), trace(evt_val_7,4), trace(evt_val_9,1)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_3,4), trace(evt_val_3,6), trace(evt_val_3,7), trace(evt_val_3,9), trace(evt_val_3,10), trace(evt_val_4,3), trace(evt_val_5,8), trace(evt_val_7,2), trace(evt_val_9,5)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,8), trace(evt_val_1,2), trace(evt_val_1,3), trace(evt_val_3,5), trace(evt_val_3,6), trace(evt_val_3,10), trace(evt_val_5,7), trace(evt_val_5,9), trace(evt_val_7,1), trace(evt_val_9,4)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,2), trace(evt_val_0,4), trace(evt_val_1,9), trace(evt_val_3,10), trace(evt_val_4,3), trace(evt_val_5,7), trace(evt_val_7,8), trace(evt_val_9,1), trace(evt_val_9,5), trace(evt_val_9,6)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_3,2), trace(evt_val_3,6), trace(evt_val_3,8), trace(evt_val_3,10), trace(evt_val_5,4), trace(evt_val_5,5), trace(evt_val_5,7), trace(evt_val_7,3), trace(evt_val_9,1), trace(evt_val_9,9)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,2), trace(evt_val_1,3), trace(evt_val_3,4), trace(evt_val_3,7), trace(evt_val_3,8), trace(evt_val_3,10), trace(evt_val_5,9), trace(evt_val_6,6), trace(evt_val_7,1), trace(evt_val_9,5)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,8), trace(evt_val_3,2), trace(evt_val_3,10), trace(evt_val_4,9), trace(evt_val_5,4), trace(evt_val_5,6), trace(evt_val_7,3), trace(evt_val_7,5), trace(evt_val_9,1), trace(evt_val_9,7)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_3,6), trace(evt_val_3,10), trace(evt_val_5,2), trace(evt_val_5,3), trace(evt_val_5,7), trace(evt_val_5,8), trace(evt_val_5,9), trace(evt_val_7,5), trace(evt_val_9,1), trace(evt_val_9,4)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_3,4), trace(evt_val_3,5), trace(evt_val_3,6), trace(evt_val_3,7), trace(evt_val_3,8), trace(evt_val_3,9), trace(evt_val_3,10), trace(evt_val_6,3), trace(evt_val_9,1), trace(evt_val_9,2)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,2), trace(evt_val_3,4), trace(evt_val_3,6), trace(evt_val_3,7), trace(evt_val_3,10), trace(evt_val_4,3), trace(evt_val_5,9), trace(evt_val_7,1), trace(evt_val_9,5), trace(evt_val_9,8)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,3), trace(evt_val_3,2), trace(evt_val_3,4), trace(evt_val_3,6), trace(evt_val_3,7), trace(evt_val_3,8), trace(evt_val_3,9), trace(evt_val_3,10), trace(evt_val_6,5)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,2), trace(evt_val_0,4), trace(evt_val_2,1), trace(evt_val_3,9), trace(evt_val_3,10), trace(evt_val_4,3), trace(evt_val_5,7), trace(evt_val_7,5), trace(evt_val_9,6), trace(evt_val_9,8)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,7), trace(evt_val_1,2), trace(evt_val_3,6), trace(evt_val_3,8), trace(evt_val_3,10), trace(evt_val_5,5), trace(evt_val_7,1), trace(evt_val_7,3), trace(evt_val_9,4), trace(evt_val_9,9)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_1,3), trace(evt_val_1,9), trace(evt_val_3,4), trace(evt_val_3,5), trace(evt_val_3,6), trace(evt_val_3,10), trace(evt_val_5,7), trace(evt_val_5,8), trace(evt_val_7,1), trace(evt_val_9,2)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,4), trace(evt_val_3,8), trace(evt_val_3,10), trace(evt_val_4,9), trace(evt_val_5,2), trace(evt_val_5,6), trace(evt_val_7,3), trace(evt_val_8,5), trace(evt_val_9,1), trace(evt_val_9,7)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_3,6), trace(evt_val_3,10), trace(evt_val_5,2), trace(evt_val_5,3), trace(evt_val_5,7), trace(evt_val_5,8), trace(evt_val_5,9), trace(evt_val_9,1), trace(evt_val_9,4), trace(evt_val_9,5)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_2,7), trace(evt_val_3,5), trace(evt_val_3,6), trace(evt_val_3,8), trace(evt_val_3,10), trace(evt_val_5,2), trace(evt_val_5,3), trace(evt_val_5,4), trace(evt_val_5,9), trace(evt_val_9,1)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_2,2), trace(evt_val_3,4), trace(evt_val_3,6), trace(evt_val_3,7), trace(evt_val_3,10), trace(evt_val_5,9), trace(evt_val_6,3), trace(evt_val_7,1), trace(evt_val_9,5), trace(evt_val_9,8)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,7), trace(evt_val_0,8), trace(evt_val_1,3), trace(evt_val_2,6), trace(evt_val_3,10), trace(evt_val_5,9), trace(evt_val_7,2), trace(evt_val_7,5), trace(evt_val_9,4)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,2), trace(evt_val_0,4), trace(evt_val_3,9), trace(evt_val_3,10), trace(evt_val_4,3), trace(evt_val_5,7), trace(evt_val_7,1), trace(evt_val_9,5), trace(evt_val_9,6), trace(evt_val_9,8)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_3,2), trace(evt_val_3,8), trace(evt_val_3,10), trace(evt_val_5,5), trace(evt_val_5,6), trace(evt_val_5,7), trace(evt_val_7,3), trace(evt_val_9,4), trace(evt_val_9,9)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,2), trace(evt_val_1,3), trace(evt_val_3,4), trace(evt_val_3,6), trace(evt_val_3,9), trace(evt_val_3,10), trace(evt_val_5,7), trace(evt_val_5,8), trace(evt_val_7,1), trace(evt_val_9,5)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_3,4), trace(evt_val_3,5), trace(evt_val_3,8), trace(evt_val_3,10), trace(evt_val_5,2), trace(evt_val_5,6), trace(evt_val_5,9), trace(evt_val_7,3), trace(evt_val_9,1), trace(evt_val_9,7)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_3,10), trace(evt_val_5,2), trace(evt_val_5,3), trace(evt_val_5,7), trace(evt_val_5,8), trace(evt_val_5,9), trace(evt_val_9,1), trace(evt_val_9,4), trace(evt_val_9,5), trace(evt_val_9,6)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_3,5), trace(evt_val_3,7), trace(evt_val_3,8), trace(evt_val_3,10), trace(evt_val_5,6), trace(evt_val_5,9), trace(evt_val_7,3), trace(evt_val_7,4), trace(evt_val_9,1), trace(evt_val_9,2)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,2), trace(evt_val_3,5), trace(evt_val_3,6), trace(evt_val_3,7), trace(evt_val_3,10), trace(evt_val_4,3), trace(evt_val_5,9), trace(evt_val_7,1), trace(evt_val_7,4), trace(evt_val_9,8)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,4), trace(evt_val_1,2), trace(evt_val_1,3), trace(evt_val_3,7), trace(evt_val_3,8), trace(evt_val_3,10), trace(evt_val_5,9), trace(evt_val_7,1), trace(evt_val_7,5), trace(evt_val_9,6)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,2), trace(evt_val_0,6), trace(evt_val_3,7), trace(evt_val_3,10), trace(evt_val_5,9), trace(evt_val_7,3), trace(evt_val_7,4), trace(evt_val_9,1), trace(evt_val_9,5), trace(evt_val_9,8)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_3,2), trace(evt_val_3,6), trace(evt_val_3,8), trace(evt_val_3,10), trace(evt_val_5,5), trace(evt_val_5,7), trace(evt_val_7,3), trace(evt_val_9,4), trace(evt_val_9,9)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,2), trace(evt_val_1,3), trace(evt_val_1,9), trace(evt_val_3,4), trace(evt_val_3,6), trace(evt_val_3,10), trace(evt_val_5,7), trace(evt_val_5,8), trace(evt_val_7,1), trace(evt_val_9,5)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,4), trace(evt_val_3,2), trace(evt_val_3,5), trace(evt_val_3,8), trace(evt_val_3,10), trace(evt_val_4,9), trace(evt_val_5,6), trace(evt_val_7,3), trace(evt_val_9,1), trace(evt_val_9,7)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_2,1), trace(evt_val_3,5), trace(evt_val_3,6), trace(evt_val_3,10), trace(evt_val_5,7), trace(evt_val_5,8), trace(evt_val_5,9), trace(evt_val_7,2), trace(evt_val_9,3), trace(evt_val_9,4)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_2,1), trace(evt_val_3,5), trace(evt_val_3,6), trace(evt_val_3,7), trace(evt_val_3,8), trace(evt_val_3,10), trace(evt_val_5,9), trace(evt_val_7,3), trace(evt_val_7,4), trace(evt_val_9,2)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_3,4), trace(evt_val_3,6), trace(evt_val_3,7), trace(evt_val_3,8), trace(evt_val_3,10), trace(evt_val_5,9), trace(evt_val_6,2), trace(evt_val_6,3), trace(evt_val_7,1), trace(evt_val_9,5)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_1,3), trace(evt_val_3,4), trace(evt_val_3,6), trace(evt_val_3,7), trace(evt_val_3,10), trace(evt_val_5,9), trace(evt_val_7,2), trace(evt_val_7,5), trace(evt_val_9,8)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,2), trace(evt_val_3,10), trace(evt_val_5,9), trace(evt_val_7,3), trace(evt_val_7,4), trace(evt_val_9,1), trace(evt_val_9,5), trace(evt_val_9,6), trace(evt_val_9,7), trace(evt_val_9,8)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_3,8), trace(evt_val_3,10), trace(evt_val_5,2), trace(evt_val_5,4), trace(evt_val_5,5), trace(evt_val_5,6), trace(evt_val_5,7), trace(evt_val_7,3), trace(evt_val_9,1), trace(evt_val_9,9)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,2), trace(evt_val_1,3), trace(evt_val_3,4), trace(evt_val_3,6), trace(evt_val_3,10), trace(evt_val_5,7), trace(evt_val_5,8), trace(evt_val_7,1), trace(evt_val_8,9), trace(evt_val_9,5)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,4), trace(evt_val_3,5), trace(evt_val_3,8), trace(evt_val_3,10), trace(evt_val_4,9), trace(evt_val_5,2), trace(evt_val_5,6), trace(evt_val_9,1), trace(evt_val_9,3), trace(evt_val_9,7)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_3,5), trace(evt_val_3,6), trace(evt_val_3,10), trace(evt_val_5,2), trace(evt_val_5,3), trace(evt_val_5,7), trace(evt_val_5,8), trace(evt_val_5,9), trace(evt_val_9,1), trace(evt_val_9,4)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,8), trace(evt_val_3,5), trace(evt_val_3,6), trace(evt_val_3,7), trace(evt_val_3,10), trace(evt_val_5,9), trace(evt_val_6,1), trace(evt_val_7,3), trace(evt_val_7,4), trace(evt_val_9,2)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_1,2), trace(evt_val_3,4), trace(evt_val_3,6), trace(evt_val_3,7), trace(evt_val_3,10), trace(evt_val_5,9), trace(evt_val_6,3), trace(evt_val_7,1), trace(evt_val_9,5), trace(evt_val_9,8)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_1,3), trace(evt_val_2,6), trace(evt_val_3,7), trace(evt_val_3,8), trace(evt_val_3,10), trace(evt_val_5,9), trace(evt_val_7,2), trace(evt_val_7,5), trace(evt_val_9,4)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,2), trace(evt_val_3,9), trace(evt_val_3,10), trace(evt_val_5,7), trace(evt_val_7,3), trace(evt_val_7,4), trace(evt_val_9,1), trace(evt_val_9,5), trace(evt_val_9,6), trace(evt_val_9,8)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,7), trace(evt_val_3,10), trace(evt_val_5,2), trace(evt_val_5,4), trace(evt_val_5,5), trace(evt_val_5,6), trace(evt_val_7,3), trace(evt_val_9,1), trace(evt_val_9,8), trace(evt_val_9,9)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,2), trace(evt_val_0,6), trace(evt_val_1,3), trace(evt_val_3,4), trace(evt_val_3,9), trace(evt_val_3,10), trace(evt_val_5,7), trace(evt_val_5,8), trace(evt_val_7,1), trace(evt_val_9,5)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,4), trace(evt_val_3,3), trace(evt_val_3,5), trace(evt_val_3,8), trace(evt_val_3,10), trace(evt_val_4,9), trace(evt_val_5,2), trace(evt_val_5,6), trace(evt_val_9,1), trace(evt_val_9,7)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_3,5), trace(evt_val_3,10), trace(evt_val_5,2), trace(evt_val_5,3), trace(evt_val_5,7), trace(evt_val_5,8), trace(evt_val_5,9), trace(evt_val_9,1), trace(evt_val_9,4), trace(evt_val_9,6)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_1,2), trace(evt_val_3,5), trace(evt_val_3,7), trace(evt_val_3,8), trace(evt_val_3,10), trace(evt_val_5,9), trace(evt_val_7,1), trace(evt_val_7,3), trace(evt_val_7,4), trace(evt_val_9,6)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,2), trace(evt_val_3,4), trace(evt_val_3,5), trace(evt_val_3,6), trace(evt_val_3,7), trace(evt_val_3,10), trace(evt_val_4,3), trace(evt_val_5,9), trace(evt_val_7,1), trace(evt_val_9,8)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,8), trace(evt_val_1,3), trace(evt_val_2,4), trace(evt_val_2,7), trace(evt_val_3,10), trace(evt_val_5,9), trace(evt_val_7,2), trace(evt_val_7,5), trace(evt_val_9,6)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_2,5), trace(evt_val_3,10), trace(evt_val_5,9), trace(evt_val_7,3), trace(evt_val_7,4), trace(evt_val_9,6), trace(evt_val_9,7), trace(evt_val_9,8)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_3,6), trace(evt_val_3,10), trace(evt_val_5,9), trace(evt_val_7,1), trace(evt_val_7,2), trace(evt_val_7,3), trace(evt_val_7,5), trace(evt_val_8,4), trace(evt_val_9,7), trace(evt_val_9,8)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,2), trace(evt_val_1,3), trace(evt_val_2,4), trace(evt_val_3,5), trace(evt_val_3,9), trace(evt_val_3,10), trace(evt_val_5,7), trace(evt_val_5,8), trace(evt_val_7,1), trace(evt_val_9,6)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,4), trace(evt_val_0,5), trace(evt_val_3,8), trace(evt_val_3,10), trace(evt_val_4,9), trace(evt_val_5,2), trace(evt_val_5,6), trace(evt_val_7,3), trace(evt_val_9,1), trace(evt_val_9,7)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_3,6), trace(evt_val_3,10), trace(evt_val_5,2), trace(evt_val_5,3), trace(evt_val_5,7), trace(evt_val_5,9), trace(evt_val_7,5), trace(evt_val_9,1), trace(evt_val_9,4), trace(evt_val_9,8)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,8), trace(evt_val_2,1), trace(evt_val_3,5), trace(evt_val_3,6), trace(evt_val_3,7), trace(evt_val_3,10), trace(evt_val_5,9), trace(evt_val_7,3), trace(evt_val_7,4), trace(evt_val_9,2)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,2), trace(evt_val_2,6), trace(evt_val_3,4), trace(evt_val_3,7), trace(evt_val_3,10), trace(evt_val_4,3), trace(evt_val_5,9), trace(evt_val_7,1), trace(evt_val_9,5), trace(evt_val_9,8)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,3), trace(evt_val_3,6), trace(evt_val_3,7), trace(evt_val_3,8), trace(evt_val_3,10), trace(evt_val_5,4), trace(evt_val_5,5), trace(evt_val_5,9), trace(evt_val_9,2)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,2), trace(evt_val_3,1), trace(evt_val_3,9), trace(evt_val_3,10), trace(evt_val_5,7), trace(evt_val_7,3), trace(evt_val_7,4), trace(evt_val_9,5), trace(evt_val_9,6), trace(evt_val_9,8)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_3,10), trace(evt_val_5,2), trace(evt_val_5,4), trace(evt_val_5,5), trace(evt_val_5,6), trace(evt_val_5,7), trace(evt_val_7,3), trace(evt_val_9,1), trace(evt_val_9,8), trace(evt_val_9,9)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,2), trace(evt_val_1,3), trace(evt_val_3,4), trace(evt_val_3,5), trace(evt_val_3,6), trace(evt_val_3,8), trace(evt_val_3,10), trace(evt_val_5,9), trace(evt_val_7,1), trace(evt_val_9,7)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_3,3), trace(evt_val_3,5), trace(evt_val_3,8), trace(evt_val_3,10), trace(evt_val_5,2), trace(evt_val_5,4), trace(evt_val_5,6), trace(evt_val_5,9), trace(evt_val_9,1), trace(evt_val_9,7)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_2,7), trace(evt_val_2,8), trace(evt_val_3,6), trace(evt_val_3,10), trace(evt_val_5,2), trace(evt_val_5,3), trace(evt_val_5,9), trace(evt_val_7,5), trace(evt_val_9,1), trace(evt_val_9,4)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_1,2), trace(evt_val_1,8), trace(evt_val_3,5), trace(evt_val_3,7), trace(evt_val_3,10), trace(evt_val_5,9), trace(evt_val_7,1), trace(evt_val_7,3), trace(evt_val_7,4), trace(evt_val_9,6)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,2), trace(evt_val_0,5), trace(evt_val_3,6), trace(evt_val_3,7), trace(evt_val_3,10), trace(evt_val_4,3), trace(evt_val_5,9), trace(evt_val_7,1), trace(evt_val_8,4), trace(evt_val_9,8)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,7), trace(evt_val_1,3), trace(evt_val_3,6), trace(evt_val_3,8), trace(evt_val_3,10), trace(evt_val_5,9), trace(evt_val_7,2), trace(evt_val_7,5), trace(evt_val_9,4)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_3,9), trace(evt_val_3,10), trace(evt_val_5,7), trace(evt_val_7,3), trace(evt_val_7,4), trace(evt_val_9,5), trace(evt_val_9,6), trace(evt_val_9,8)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_3,7), trace(evt_val_3,10), trace(evt_val_5,2), trace(evt_val_5,4), trace(evt_val_5,5), trace(evt_val_5,6), trace(evt_val_7,3), trace(evt_val_9,1), trace(evt_val_9,8), trace(evt_val_9,9)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,2), trace(evt_val_1,3), trace(evt_val_2,9), trace(evt_val_3,4), trace(evt_val_3,6), trace(evt_val_3,10), trace(evt_val_5,7), trace(evt_val_5,8), trace(evt_val_7,1), trace(evt_val_9,5)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,4), trace(evt_val_2,3), trace(evt_val_3,5), trace(evt_val_3,8), trace(evt_val_3,10), trace(evt_val_4,9), trace(evt_val_5,2), trace(evt_val_5,6), trace(evt_val_9,1), trace(evt_val_9,7)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_3,6), trace(evt_val_3,8), trace(evt_val_3,10), trace(evt_val_5,2), trace(evt_val_5,3), trace(evt_val_5,7), trace(evt_val_7,5), trace(evt_val_9,1), trace(evt_val_9,4), trace(evt_val_9,9)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_3,5), trace(evt_val_3,6), trace(evt_val_3,7), trace(evt_val_3,8), trace(evt_val_3,10), trace(evt_val_5,9), trace(evt_val_7,1), trace(evt_val_7,3), trace(evt_val_7,4), trace(evt_val_9,2)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,2), trace(evt_val_3,6), trace(evt_val_3,7), trace(evt_val_3,10), trace(evt_val_4,3), trace(evt_val_5,9), trace(evt_val_7,1), trace(evt_val_7,4), trace(evt_val_9,5), trace(evt_val_9,8)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_1,3), trace(evt_val_3,4), trace(evt_val_3,6), trace(evt_val_3,9), trace(evt_val_3,10), trace(evt_val_5,8), trace(evt_val_7,2), trace(evt_val_7,5), trace(evt_val_9,7)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,2), trace(evt_val_2,1), trace(evt_val_3,9), trace(evt_val_3,10), trace(evt_val_5,7), trace(evt_val_7,3), trace(evt_val_7,4), trace(evt_val_9,5), trace(evt_val_9,6), trace(evt_val_9,8)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_3,9), trace(evt_val_3,10), trace(evt_val_5,2), trace(evt_val_5,4), trace(evt_val_5,5), trace(evt_val_5,6), trace(evt_val_5,7), trace(evt_val_7,3), trace(evt_val_9,1), trace(evt_val_9,8)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,2), trace(evt_val_1,3), trace(evt_val_2,8), trace(evt_val_3,4), trace(evt_val_3,6), trace(evt_val_3,10), trace(evt_val_5,7), trace(evt_val_7,1), trace(evt_val_9,5), trace(evt_val_9,9)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,4), trace(evt_val_3,5), trace(evt_val_3,8), trace(evt_val_3,10), trace(evt_val_4,9), trace(evt_val_5,2), trace(evt_val_5,3), trace(evt_val_5,6), trace(evt_val_9,1), trace(evt_val_9,7)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_3,6), trace(evt_val_3,8), trace(evt_val_3,10), trace(evt_val_5,2), trace(evt_val_5,3), trace(evt_val_5,7), trace(evt_val_5,9), trace(evt_val_9,1), trace(evt_val_9,4), trace(evt_val_9,5)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_3,5), trace(evt_val_3,6), trace(evt_val_3,7), trace(evt_val_3,10), trace(evt_val_5,9), trace(evt_val_7,1), trace(evt_val_7,3), trace(evt_val_7,4), trace(evt_val_7,8), trace(evt_val_9,2)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,2), trace(evt_val_1,6), trace(evt_val_3,7), trace(evt_val_3,10), trace(evt_val_4,3), trace(evt_val_5,9), trace(evt_val_7,1), trace(evt_val_7,4), trace(evt_val_9,5), trace(evt_val_9,8)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,2), trace(evt_val_1,3), trace(evt_val_1,7), trace(evt_val_1,8), trace(evt_val_3,6), trace(evt_val_3,10), trace(evt_val_5,9), trace(evt_val_7,1), trace(evt_val_7,5), trace(evt_val_9,4)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_2,5), trace(evt_val_3,9), trace(evt_val_3,10), trace(evt_val_5,7), trace(evt_val_7,3), trace(evt_val_7,4), trace(evt_val_9,6), trace(evt_val_9,8)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_1,7), trace(evt_val_3,10), trace(evt_val_5,2), trace(evt_val_5,4), trace(evt_val_5,5), trace(evt_val_5,6), trace(evt_val_7,3), trace(evt_val_9,1), trace(evt_val_9,8), trace(evt_val_9,9)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,2), trace(evt_val_1,3), trace(evt_val_3,4), trace(evt_val_3,6), trace(evt_val_3,10), trace(evt_val_5,7), trace(evt_val_5,8), trace(evt_val_7,1), trace(evt_val_9,5), trace(evt_val_9,9)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,4), trace(evt_val_3,8), trace(evt_val_3,10), trace(evt_val_4,9), trace(evt_val_5,2), trace(evt_val_5,6), trace(evt_val_6,5), trace(evt_val_7,3), trace(evt_val_9,1), trace(evt_val_9,7)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_3,6), trace(evt_val_3,10), trace(evt_val_5,3), trace(evt_val_5,7), trace(evt_val_5,8), trace(evt_val_5,9), trace(evt_val_7,2), trace(evt_val_7,5), trace(evt_val_9,1), trace(evt_val_9,4)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_3,5), trace(evt_val_3,6), trace(evt_val_3,7), trace(evt_val_3,10), trace(evt_val_5,8), trace(evt_val_5,9), trace(evt_val_7,1), trace(evt_val_7,3), trace(evt_val_7,4), trace(evt_val_9,2)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_2,2), trace(evt_val_2,6), trace(evt_val_3,5), trace(evt_val_3,7), trace(evt_val_3,10), trace(evt_val_5,9), trace(evt_val_6,3), trace(evt_val_7,1), trace(evt_val_7,4), trace(evt_val_9,8)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_1,3), trace(evt_val_3,6), trace(evt_val_3,8), trace(evt_val_3,10), trace(evt_val_5,7), trace(evt_val_5,9), trace(evt_val_7,2), trace(evt_val_7,5), trace(evt_val_9,4)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_3,10), trace(evt_val_5,9), trace(evt_val_7,3), trace(evt_val_7,4), trace(evt_val_9,5), trace(evt_val_9,6), trace(evt_val_9,7), trace(evt_val_9,8)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_3,10), trace(evt_val_5,2), trace(evt_val_5,4), trace(evt_val_5,5), trace(evt_val_5,6), trace(evt_val_7,3), trace(evt_val_8,7), trace(evt_val_9,1), trace(evt_val_9,8), trace(evt_val_9,9)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,2), trace(evt_val_1,3), trace(evt_val_3,4), trace(evt_val_3,10), trace(evt_val_5,7), trace(evt_val_5,8), trace(evt_val_7,1), trace(evt_val_8,5), trace(evt_val_9,6), trace(evt_val_9,9)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,6), trace(evt_val_2,1), trace(evt_val_2,7), trace(evt_val_3,2), trace(evt_val_3,5), trace(evt_val_3,8), trace(evt_val_3,10), trace(evt_val_4,9), trace(evt_val_6,3), trace(evt_val_8,4)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_3,10), trace(evt_val_5,2), trace(evt_val_5,3), trace(evt_val_5,7), trace(evt_val_5,8), trace(evt_val_5,9), trace(evt_val_7,5), trace(evt_val_9,1), trace(evt_val_9,4), trace(evt_val_9,6)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,8), trace(evt_val_3,5), trace(evt_val_3,6), trace(evt_val_3,7), trace(evt_val_3,10), trace(evt_val_5,9), trace(evt_val_7,1), trace(evt_val_7,3), trace(evt_val_7,4), trace(evt_val_9,2)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_0,6), trace(evt_val_0,9), trace(evt_val_3,5), trace(evt_val_3,7), trace(evt_val_3,8), trace(evt_val_3,10), trace(evt_val_4,3), trace(evt_val_6,4)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,7), trace(evt_val_1,3), trace(evt_val_3,4), trace(evt_val_3,6), trace(evt_val_3,10), trace(evt_val_5,9), trace(evt_val_7,2), trace(evt_val_7,5), trace(evt_val_9,8)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_3,9), trace(evt_val_3,10), trace(evt_val_5,6), trace(evt_val_5,7), trace(evt_val_7,3), trace(evt_val_7,4), trace(evt_val_9,5), trace(evt_val_9,8)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_3,10), trace(evt_val_5,2), trace(evt_val_5,4), trace(evt_val_5,5), trace(evt_val_5,6), trace(evt_val_6,7), trace(evt_val_7,3), trace(evt_val_9,1), trace(evt_val_9,8), trace(evt_val_9,9)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,2), trace(evt_val_1,3), trace(evt_val_2,4), trace(evt_val_3,6), trace(evt_val_3,9), trace(evt_val_3,10), trace(evt_val_5,7), trace(evt_val_5,8), trace(evt_val_7,1), trace(evt_val_9,5)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,4), trace(evt_val_2,5), trace(evt_val_3,8), trace(evt_val_3,10), trace(evt_val_4,9), trace(evt_val_5,2), trace(evt_val_5,6), trace(evt_val_7,3), trace(evt_val_9,1), trace(evt_val_9,7)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_2,4), trace(evt_val_3,6), trace(evt_val_3,10), trace(evt_val_5,2), trace(evt_val_5,3), trace(evt_val_5,7), trace(evt_val_5,8), trace(evt_val_5,9), trace(evt_val_7,5), trace(evt_val_9,1)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_2,4), trace(evt_val_3,2), trace(evt_val_3,3), trace(evt_val_3,5), trace(evt_val_3,7), trace(evt_val_3,8), trace(evt_val_3,9), trace(evt_val_3,10), trace(evt_val_6,6), trace(evt_val_8,1)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,2), trace(evt_val_0,6), trace(evt_val_3,7), trace(evt_val_3,10), trace(evt_val_4,3), trace(evt_val_5,9), trace(evt_val_7,1), trace(evt_val_7,4), trace(evt_val_9,5), trace(evt_val_9,8)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_1,3), trace(evt_val_2,8), trace(evt_val_3,6), trace(evt_val_3,10), trace(evt_val_5,7), trace(evt_val_5,9), trace(evt_val_7,2), trace(evt_val_7,5), trace(evt_val_9,4)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_3,9), trace(evt_val_3,10), trace(evt_val_4,3), trace(evt_val_5,7), trace(evt_val_9,4), trace(evt_val_9,5), trace(evt_val_9,6), trace(evt_val_9,8)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,6), trace(evt_val_3,7), trace(evt_val_3,10), trace(evt_val_5,2), trace(evt_val_5,4), trace(evt_val_5,5), trace(evt_val_7,3), trace(evt_val_9,1), trace(evt_val_9,8), trace(evt_val_9,9)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,2), trace(evt_val_1,3), trace(evt_val_3,4), trace(evt_val_3,6), trace(evt_val_3,10), trace(evt_val_5,7), trace(evt_val_5,8), trace(evt_val_6,9), trace(evt_val_7,1), trace(evt_val_9,5)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,3), trace(evt_val_1,2), trace(evt_val_3,5), trace(evt_val_3,8), trace(evt_val_3,10), trace(evt_val_4,9), trace(evt_val_5,6), trace(evt_val_7,1), trace(evt_val_9,4), trace(evt_val_9,7)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_2,8), trace(evt_val_3,6), trace(evt_val_3,10), trace(evt_val_5,2), trace(evt_val_5,3), trace(evt_val_5,7), trace(evt_val_5,9), trace(evt_val_7,5), trace(evt_val_9,1), trace(evt_val_9,4)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_3,5), trace(evt_val_3,6), trace(evt_val_3,7), trace(evt_val_3,8), trace(evt_val_3,10), trace(evt_val_5,2), trace(evt_val_5,9), trace(evt_val_7,3), trace(evt_val_7,4), trace(evt_val_9,1)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,2), trace(evt_val_3,5), trace(evt_val_3,7), trace(evt_val_3,10), trace(evt_val_4,3), trace(evt_val_5,9), trace(evt_val_7,1), trace(evt_val_7,4), trace(evt_val_9,6), trace(evt_val_9,8)]
# ...
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_3,11), trace(evt_val_4,4), trace(evt_val_5,3), trace(evt_val_5,8), trace(evt_val_5,10), trace(evt_val_8,9), trace(evt_val_9,2), trace(evt_val_9,5), trace(evt_val_9,6), trace(evt_val_9,7)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,6), trace(evt_val_1,5), trace(evt_val_3,9), trace(evt_val_3,11), trace(evt_val_5,3), trace(evt_val_5,10), trace(evt_val_7,4), trace(evt_val_7,8), trace(evt_val_9,2), trace(evt_val_9,7)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_2,1), trace(evt_val_3,3), trace(evt_val_3,10), trace(evt_val_3,11), trace(evt_val_5,4), trace(evt_val_5,5), trace(evt_val_5,6), trace(evt_val_7,8), trace(evt_val_7,9), trace(evt_val_9,2), trace(evt_val_9,7)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,2), trace(evt_val_0,5), trace(evt_val_2,10), trace(evt_val_3,11), trace(evt_val_5,4), trace(evt_val_5,8), trace(evt_val_7,3), trace(evt_val_7,9), trace(evt_val_8,6), trace(evt_val_9,1), trace(evt_val_9,7)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,2), trace(evt_val_3,11), trace(evt_val_4,4), trace(evt_val_4,8), trace(evt_val_5,6), trace(evt_val_5,7), trace(evt_val_5,9), trace(evt_val_5,10), trace(evt_val_7,1), trace(evt_val_7,3), trace(evt_val_9,5)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,4), trace(evt_val_1,8), trace(evt_val_3,6), trace(evt_val_3,11), trace(evt_val_5,3), trace(evt_val_5,10), trace(evt_val_7,5), trace(evt_val_9,2), trace(evt_val_9,7), trace(evt_val_9,9)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_3,7), trace(evt_val_3,8), trace(evt_val_3,10), trace(evt_val_3,11), trace(evt_val_5,2), trace(evt_val_5,4), trace(evt_val_5,6), trace(evt_val_7,9), trace(evt_val_9,1), trace(evt_val_9,3), trace(evt_val_9,5)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,10), trace(evt_val_3,3), trace(evt_val_3,11), trace(evt_val_5,4), trace(evt_val_5,5), trace(evt_val_5,6), trace(evt_val_5,8), trace(evt_val_5,9), trace(evt_val_7,1), trace(evt_val_9,2), trace(evt_val_9,7)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,2), trace(evt_val_3,11), trace(evt_val_4,4), trace(evt_val_5,3), trace(evt_val_5,10), trace(evt_val_6,8), trace(evt_val_8,9), trace(evt_val_9,1), trace(evt_val_9,5), trace(evt_val_9,6), trace(evt_val_9,7)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_3,4), trace(evt_val_3,8), trace(evt_val_3,9), trace(evt_val_3,11), trace(evt_val_4,5), trace(evt_val_6,6), trace(evt_val_6,10), trace(evt_val_9,3), trace(evt_val_9,7)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,7), trace(evt_val_3,3), trace(evt_val_3,8), trace(evt_val_3,11), trace(evt_val_5,4), trace(evt_val_5,5), trace(evt_val_5,6), trace(evt_val_7,9), trace(evt_val_9,1), trace(evt_val_9,2), trace(evt_val_9,10)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_3,10), trace(evt_val_3,11), trace(evt_val_5,2), trace(evt_val_5,4), trace(evt_val_5,5), trace(evt_val_5,8), trace(evt_val_7,3), trace(evt_val_7,9), trace(evt_val_8,6), trace(evt_val_9,1), trace(evt_val_9,7)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,2), trace(evt_val_0,5), trace(evt_val_0,10), trace(evt_val_3,11), trace(evt_val_5,4), trace(evt_val_5,8), trace(evt_val_7,3), trace(evt_val_7,9), trace(evt_val_8,6), trace(evt_val_9,1), trace(evt_val_9,7)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,5), trace(evt_val_1,2), trace(evt_val_3,11), trace(evt_val_5,4), trace(evt_val_5,8), trace(evt_val_6,10), trace(evt_val_7,1), trace(evt_val_7,9), trace(evt_val_8,6), trace(evt_val_9,3), trace(evt_val_9,7)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,4), trace(evt_val_0,8), trace(evt_val_2,10), trace(evt_val_3,5), trace(evt_val_3,7), trace(evt_val_3,11), trace(evt_val_5,2), trace(evt_val_5,6), trace(evt_val_7,9), trace(evt_val_9,1), trace(evt_val_9,3)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_2,7), trace(evt_val_2,10), trace(evt_val_3,3), trace(evt_val_3,11), trace(evt_val_5,4), trace(evt_val_5,5), trace(evt_val_5,6), trace(evt_val_5,8), trace(evt_val_5,9), trace(evt_val_7,1), trace(evt_val_9,2)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_0,3), trace(evt_val_0,5), trace(evt_val_2,8), trace(evt_val_3,6), trace(evt_val_3,10), trace(evt_val_3,11), trace(evt_val_4,4), trace(evt_val_4,7), trace(evt_val_8,9)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_1,5), trace(evt_val_3,9), trace(evt_val_3,11), trace(evt_val_5,3), trace(evt_val_6,6), trace(evt_val_7,4), trace(evt_val_7,8), trace(evt_val_9,2), trace(evt_val_9,7), trace(evt_val_9,10)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,7), trace(evt_val_0,10), trace(evt_val_3,3), trace(evt_val_3,8), trace(evt_val_3,11), trace(evt_val_5,4), trace(evt_val_5,5), trace(evt_val_5,6), trace(evt_val_7,9), trace(evt_val_9,1), trace(evt_val_9,2)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_1,8), trace(evt_val_3,11), trace(evt_val_5,4), trace(evt_val_5,6), trace(evt_val_5,7), trace(evt_val_5,9), trace(evt_val_5,10), trace(evt_val_6,5), trace(evt_val_7,1), trace(evt_val_7,3), trace(evt_val_9,2)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_1,8), trace(evt_val_2,4), trace(evt_val_3,2), trace(evt_val_3,6), trace(evt_val_3,11), trace(evt_val_5,3), trace(evt_val_5,5), trace(evt_val_5,10), trace(evt_val_7,7), trace(evt_val_9,1), trace(evt_val_9,9)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_1,4), trace(evt_val_3,5), trace(evt_val_3,11), trace(evt_val_5,8), trace(evt_val_6,10), trace(evt_val_7,3), trace(evt_val_7,9), trace(evt_val_8,6), trace(evt_val_9,1), trace(evt_val_9,2), trace(evt_val_9,7)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,4), trace(evt_val_0,8), trace(evt_val_3,7), trace(evt_val_3,11), trace(evt_val_5,2), trace(evt_val_5,6), trace(evt_val_7,9), trace(evt_val_9,1), trace(evt_val_9,3), trace(evt_val_9,5), trace(evt_val_9,10)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,9), trace(evt_val_0,10), trace(evt_val_3,3), trace(evt_val_3,7), trace(evt_val_3,11), trace(evt_val_5,4), trace(evt_val_5,5), trace(evt_val_5,6), trace(evt_val_5,8), trace(evt_val_8,1), trace(evt_val_9,2)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_1,5), trace(evt_val_2,1), trace(evt_val_3,11), trace(evt_val_5,3), trace(evt_val_5,10), trace(evt_val_7,4), trace(evt_val_7,8), trace(evt_val_8,9), trace(evt_val_9,2), trace(evt_val_9,6), trace(evt_val_9,7)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,7), trace(evt_val_1,5), trace(evt_val_3,9), trace(evt_val_3,11), trace(evt_val_5,3), trace(evt_val_5,10), trace(evt_val_6,6), trace(evt_val_7,4), trace(evt_val_7,8), trace(evt_val_9,2)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,7), trace(evt_val_3,8), trace(evt_val_3,11), trace(evt_val_4,10), trace(evt_val_5,4), trace(evt_val_5,5), trace(evt_val_5,6), trace(evt_val_7,1), trace(evt_val_7,9), trace(evt_val_8,3), trace(evt_val_9,2)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,4), trace(evt_val_0,5), trace(evt_val_3,11), trace(evt_val_4,8), trace(evt_val_5,6), trace(evt_val_5,7), trace(evt_val_5,9), trace(evt_val_5,10), trace(evt_val_7,1), trace(evt_val_7,3), trace(evt_val_9,2)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,4), trace(evt_val_1,8), trace(evt_val_3,2), trace(evt_val_3,3), trace(evt_val_3,6), trace(evt_val_3,11), trace(evt_val_5,10), trace(evt_val_7,5), trace(evt_val_9,7), trace(evt_val_9,9)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,2), trace(evt_val_0,5), trace(evt_val_2,10), trace(evt_val_3,11), trace(evt_val_4,6), trace(evt_val_5,4), trace(evt_val_5,8), trace(evt_val_7,3), trace(evt_val_7,9), trace(evt_val_9,1), trace(evt_val_9,7)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,4), trace(evt_val_3,7), trace(evt_val_3,11), trace(evt_val_5,2), trace(evt_val_5,6), trace(evt_val_6,10), trace(evt_val_7,8), trace(evt_val_7,9), trace(evt_val_9,1), trace(evt_val_9,3), trace(evt_val_9,5)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,10), trace(evt_val_3,3), trace(evt_val_3,11), trace(evt_val_5,4), trace(evt_val_5,5), trace(evt_val_5,6), trace(evt_val_5,7), trace(evt_val_5,8), trace(evt_val_5,9), trace(evt_val_7,1), trace(evt_val_9,2)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,2), trace(evt_val_0,7), trace(evt_val_2,10), trace(evt_val_3,11), trace(evt_val_4,4), trace(evt_val_8,9), trace(evt_val_9,1), trace(evt_val_9,3), trace(evt_val_9,5), trace(evt_val_9,6), trace(evt_val_9,8)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_1,5), trace(evt_val_2,6), trace(evt_val_3,9), trace(evt_val_3,11), trace(evt_val_5,3), trace(evt_val_6,10), trace(evt_val_7,4), trace(evt_val_7,8), trace(evt_val_9,2), trace(evt_val_9,7)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,7), trace(evt_val_3,3), trace(evt_val_3,8), trace(evt_val_3,11), trace(evt_val_5,4), trace(evt_val_5,5), trace(evt_val_5,6), trace(evt_val_7,9), trace(evt_val_7,10), trace(evt_val_9,1), trace(evt_val_9,2)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_2,8), trace(evt_val_3,11), trace(evt_val_5,4), trace(evt_val_5,6), trace(evt_val_5,7), trace(evt_val_5,9), trace(evt_val_5,10), trace(evt_val_6,5), trace(evt_val_7,1), trace(evt_val_7,3), trace(evt_val_9,2)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_1,8), trace(evt_val_3,2), trace(evt_val_3,6), trace(evt_val_3,11), trace(evt_val_5,3), trace(evt_val_5,4), trace(evt_val_5,10), trace(evt_val_7,5), trace(evt_val_9,1), trace(evt_val_9,7), trace(evt_val_9,9)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,2), trace(evt_val_0,5), trace(evt_val_3,10), trace(evt_val_3,11), trace(evt_val_4,6), trace(evt_val_5,4), trace(evt_val_5,8), trace(evt_val_7,3), trace(evt_val_7,9), trace(evt_val_9,1), trace(evt_val_9,7)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,4), trace(evt_val_0,8), trace(evt_val_3,7), trace(evt_val_3,11), trace(evt_val_5,2), trace(evt_val_5,6), trace(evt_val_6,10), trace(evt_val_7,9), trace(evt_val_9,1), trace(evt_val_9,3), trace(evt_val_9,5)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_2,7), trace(evt_val_3,3), trace(evt_val_3,11), trace(evt_val_5,4), trace(evt_val_5,5), trace(evt_val_5,6), trace(evt_val_5,8), trace(evt_val_5,9), trace(evt_val_7,1), trace(evt_val_9,2), trace(evt_val_9,10)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,2), trace(evt_val_3,11), trace(evt_val_4,4), trace(evt_val_4,8), trace(evt_val_5,3), trace(evt_val_5,10), trace(evt_val_8,9), trace(evt_val_9,1), trace(evt_val_9,5), trace(evt_val_9,6), trace(evt_val_9,7)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_1,5), trace(evt_val_3,7), trace(evt_val_3,9), trace(evt_val_3,11), trace(evt_val_5,3), trace(evt_val_5,10), trace(evt_val_6,6), trace(evt_val_7,4), trace(evt_val_7,8), trace(evt_val_9,2)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,3), trace(evt_val_0,7), trace(evt_val_3,8), trace(evt_val_3,11), trace(evt_val_5,4), trace(evt_val_5,5), trace(evt_val_5,6), trace(evt_val_7,9), trace(evt_val_7,10), trace(evt_val_9,1), trace(evt_val_9,2)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_3,11), trace(evt_val_5,4), trace(evt_val_5,6), trace(evt_val_5,7), trace(evt_val_5,9), trace(evt_val_5,10), trace(evt_val_6,5), trace(evt_val_7,1), trace(evt_val_7,3), trace(evt_val_7,8), trace(evt_val_9,2)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_1,5), trace(evt_val_1,8), trace(evt_val_3,2), trace(evt_val_3,6), trace(evt_val_3,11), trace(evt_val_5,3), trace(evt_val_5,10), trace(evt_val_7,4), trace(evt_val_9,1), trace(evt_val_9,7), trace(evt_val_9,9)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,2), trace(evt_val_0,5), trace(evt_val_2,10), trace(evt_val_3,11), trace(evt_val_5,8), trace(evt_val_7,1), trace(evt_val_7,3), trace(evt_val_7,4), trace(evt_val_7,9), trace(evt_val_8,6), trace(evt_val_9,7)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_3,7), trace(evt_val_3,11), trace(evt_val_5,2), trace(evt_val_5,6), trace(evt_val_6,4), trace(evt_val_6,10), trace(evt_val_7,8), trace(evt_val_7,9), trace(evt_val_9,1), trace(evt_val_9,3), trace(evt_val_9,5)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,4), trace(evt_val_0,5), trace(evt_val_0,7), trace(evt_val_0,9), trace(evt_val_0,10), trace(evt_val_3,2), trace(evt_val_3,3), trace(evt_val_3,8), trace(evt_val_3,11), trace(evt_val_4,6), trace(evt_val_6,1)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_3,7), trace(evt_val_3,11), trace(evt_val_4,4), trace(evt_val_4,8), trace(evt_val_5,3), trace(evt_val_5,10), trace(evt_val_8,9), trace(evt_val_9,2), trace(evt_val_9,5), trace(evt_val_9,6)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_1,5), trace(evt_val_2,1), trace(evt_val_3,7), trace(evt_val_3,9), trace(evt_val_3,11), trace(evt_val_5,3), trace(evt_val_5,10), trace(evt_val_6,6), trace(evt_val_7,4), trace(evt_val_7,8), trace(evt_val_9,2)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,3), trace(evt_val_0,7), trace(evt_val_2,1), trace(evt_val_3,8), trace(evt_val_3,11), trace(evt_val_4,10), trace(evt_val_5,4), trace(evt_val_5,5), trace(evt_val_5,6), trace(evt_val_7,9), trace(evt_val_9,2)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_2,8), trace(evt_val_3,11), trace(evt_val_5,4), trace(evt_val_5,5), trace(evt_val_5,6), trace(evt_val_5,7), trace(evt_val_5,9), trace(evt_val_5,10), trace(evt_val_7,1), trace(evt_val_7,3), trace(evt_val_9,2)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_1,8), trace(evt_val_3,2), trace(evt_val_3,6), trace(evt_val_3,11), trace(evt_val_5,3), trace(evt_val_5,10), trace(evt_val_7,5), trace(evt_val_8,4), trace(evt_val_9,1), trace(evt_val_9,7), trace(evt_val_9,9)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,10), trace(evt_val_1,4), trace(evt_val_3,11), trace(evt_val_5,8), trace(evt_val_7,3), trace(evt_val_7,5), trace(evt_val_7,9), trace(evt_val_8,6), trace(evt_val_9,1), trace(evt_val_9,2), trace(evt_val_9,7)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,4), trace(evt_val_0,8), trace(evt_val_3,7), trace(evt_val_3,11), trace(evt_val_5,2), trace(evt_val_5,6), trace(evt_val_5,10), trace(evt_val_7,9), trace(evt_val_9,1), trace(evt_val_9,3), trace(evt_val_9,5)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,10), trace(evt_val_3,3), trace(evt_val_3,7), trace(evt_val_3,8), trace(evt_val_3,11), trace(evt_val_5,4), trace(evt_val_5,5), trace(evt_val_5,6), trace(evt_val_5,9), trace(evt_val_7,1), trace(evt_val_9,2)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,2), trace(evt_val_0,9), trace(evt_val_3,11), trace(evt_val_4,4), trace(evt_val_4,8), trace(evt_val_5,3), trace(evt_val_5,10), trace(evt_val_9,1), trace(evt_val_9,5), trace(evt_val_9,6), trace(evt_val_9,7)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_2,5), trace(evt_val_3,8), trace(evt_val_3,9), trace(evt_val_3,11), trace(evt_val_5,3), trace(evt_val_5,4), trace(evt_val_5,10), trace(evt_val_6,6), trace(evt_val_9,1), trace(evt_val_9,2), trace(evt_val_9,7)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_3,8), trace(evt_val_3,9), trace(evt_val_3,11), trace(evt_val_5,4), trace(evt_val_5,5), trace(evt_val_5,6), trace(evt_val_7,3), trace(evt_val_7,10), trace(evt_val_9,1), trace(evt_val_9,2), trace(evt_val_9,7)]
# DEBUG:ASP generator: Traces generated :[trace(evt_val_3,11), trace(evt_val_5,4), trace(evt_val_5,5), trace(evt_val_5,6), trace(evt_val_5,7), trace(evt_val_5,9), trace(evt_val_5,10), trace(evt_val_7,1), trace(evt_val_7,3), trace(evt_val_9,2), trace(evt_val_9,8)]
# DEBUG:ASP generator:Clingo Result :SAT
# DEBUG:ASP generator:Traces generated. Positive: 10000 Neg: 0. Parsing Trace results.
# DEBUG:ASP generator:Parsing result traces
# DEBUG:ASP generator:Generating Pm4py log
# DEBUG:ASP generator:Pm4py generated but not saved yet

# %%
# Save file
model_name = 'M_TEST'
asp_gen.to_xes(f"{model_name}.xes")
# Out:
# exporting log, completed traces :: 100%|██████████| 10000/10000 [00:02<00:00, 4579.95it/s]

# %% [markdown]
# 2 Conformance checking
#
# 2.1 Check between event log and normative model (results in deviation log)

# %%
from Declare4Py.ProcessModels.DeclareModel import DeclareModel
from Declare4Py.D4PyEventLog import D4PyEventLog

# %%
log_path = os.path.join("M_TEST.xes")

# %%
# Load data
event_log = D4PyEventLog(case_name="case:concept:name")
event_log.parse_xes_log(log_path)

model_path = os.path.join(path_normative_model)
declare_model = DeclareModel().parse_from_file(model_path)

# Show constraints in normative model
model_constraints = declare_model.get_decl_model_constraints()
model_constraints
# Out:
# parsing log, completed traces :: 100%|██████████| 10000/10000 [00:02<00:00, 3615.08it/s]
# ['Init[g] | | |',
#  'End[d] | | |',
#  'Chain Precedence[c, f] | | |',
#  'Alternate Response[h, f] | | |',
#  'Precedence[h, b] | | |',
#  'Responded Existence[j, f] | | |',
#  'Chain Precedence[j, f] | | |',
#  'Response[a, c] | | |',
#  'Alternate Precedence[a, e] | | |',
#  'Responded Existence[g, c] | | |']

# %%
from Declare4Py.ProcessMiningTasks.ConformanceChecking.MPDeclareAnalyzer import MPDeclareAnalyzer
from Declare4Py.ProcessMiningTasks.ConformanceChecking.MPDeclareResultsBrowser import MPDeclareResultsBrowser

# %%
# conformance check between eventlog and normative model
basic_checker = MPDeclareAnalyzer(log=event_log, declare_model=declare_model, consider_vacuity=True)
conf_check_res: MPDeclareResultsBrowser = basic_checker.run()

# %%
# show results
df_norm = conf_check_res.get_metric(metric="state")

print("Conformant cases: " +  str(df_norm.loc[(df_norm==1).all(axis=1)].shape[0]) + 
      "\nNon-conformant cases: " + str(df_norm.loc[(df_norm==0).any(axis=1)].shape[0]))
# Out:
# Conformant cases: 3
# Non-conformant cases: 9997

# %%
df_norm.to_csv("M_rules_norm_TEST.csv")

# %% [markdown]
# 2.1 Check between deviation log and auditor model (results in anomaly log)

# %%
from Declare4Py.ProcessModels.DeclareModel import DeclareModel
from Declare4Py.ProcessMiningTasks.ConformanceChecking.MPDeclareAnalyzer import MPDeclareAnalyzer
from Declare4Py.ProcessMiningTasks.ConformanceChecking.MPDeclareResultsBrowser import MPDeclareResultsBrowser

# %%
model_path = os.path.join(path_auditor_model)
declare_model = DeclareModel().parse_from_file(model_path)

# Show constraints in auditor model
model_constraints = declare_model.get_decl_model_constraints()
model_constraints
# Out:
# ['End[d] | | |',
#  'Response[h, f] | | |',
#  'Precedence[h, b] | | |',
#  'Responded Existence[j, f] | | |',
#  'Alternate Precedence[j, f] | | |',
#  'Responded Existence[a, c] | | |',
#  'Precedence[a, e] | | |',
#  'Responded Existence[g, c] | | |']

# %%
# conformance check between deviation log and auditor model (deviation log = event log in this case, because all cases were non-conformant)
basic_checker = MPDeclareAnalyzer(log=event_log, declare_model=declare_model, consider_vacuity=True)
conf_check_res: MPDeclareResultsBrowser = basic_checker.run()

# %%
# show results
df_audit = conf_check_res.get_metric(metric="state")

print("Conformant cases: " +  str(df_norm.loc[(df_audit==1).all(axis=1)].shape[0]) + 
      "\nNon-conformant cases: " + str(df_norm.loc[(df_audit==0).any(axis=1)].shape[0]))
# Out:
# Conformant cases: 1655
# Non-conformant cases: 8345

# %%
df_audit.to_csv("M_rules_auditor_TEST.csv")

# %% [markdown]
# 3 Label deviations as Anomaly (1) or Exception (0)

# %%
import random
import numpy as np
import pandas as pd

# %%
df_norm = pd.read_csv("M_rules_norm_TEST.csv")
df_audit = pd.read_csv("M_rules_auditor_TEST.csv")

# log_path = os.path.join("M_eventlog.xes")
# event_log = D4PyEventLog(case_name="case:concept:name")
# event_log.parse_xes_log(log_path)

# %%
# Get deviations and anomalies
violations_auditor = df_audit[(df_audit == 0).any(axis='columns')]
violations_norm = df_norm[(df_norm == 0).any(axis='columns')]

# Generate lists to get indices
anomalies = violations_auditor.index.values.tolist() 
deviations = violations_norm.index.values.tolist() 
exceptions = np.setdiff1d(deviations, anomalies)

# %%
violations_auditor
# Out:
#       Unnamed: 0  End[d] | | |  Response[h, f] | | |  Precedence[h, b] | | |
# 0              0             1                     1                       1  \
# 6              6             1                     1                       1
# 7              7             1                     1                       1
# 8              8             1                     1                       1
# 11            11             1                     1                       1
# ...          ...           ...                   ...                     ...
# 9995        9995             1                     1                       1
# 9996        9996             1                     1                       1
# 9997        9997             1                     1                       1
# 9998        9998             1                     0                       1
# 9999        9999             1                     1                       1
#
#       Responded Existence[j, f] | | |  Alternate Precedence[j, f] | | |
# 0                                   1                                 1  \
# 6                                   1                                 1
# 7                                   1                                 0
# 8                                   1                                 1
# 11                                  0                                 1
# ...                               ...                               ...
# 9995                                1                                 0
# 9996                                1                                 1
# 9997                                1                                 0
# 9998                                1                                 0
# 9999                                1                                 0
#
#       Responded Existence[a, c] | | |  Precedence[a, e] | | |
# 0                                   1                       1  \
# 6                                   0                       1
# 7                                   1                       1
# 8                                   0                       1
# 11                                  0                       1
# ...                               ...                     ...
# 9995                                0                       1
# 9996                                0                       1
# 9997                                1                       1
# 9998                                1                       1
# 9999                                1                       1
#
#       Responded Existence[g, c] | | |
# 0                                   1
# 6                                   1
# 7                                   1
# 8                                   1
# 11                                  1
# ...                               ...
# 9995                                1
# 9996                                1
# 9997                                1
# 9998                                1
# 9999                                1
#
# [8346 rows x 9 columns]

# %%
len(deviations)
# Out:
# 9997

# %%
event_log.to_dataframe()
df_log = event_log.get_log()

# %%
df_log
# Out:
#        concept:name lifecycle:transition                   time:timestamp
# 0                 a             complete 2024-05-22 18:04:19.882815+00:00  \
# 1                 c             complete 2024-05-22 19:14:47.882815+00:00
# 2                 c             complete 2024-05-22 19:57:48.882815+00:00
# 3                 c             complete 2024-05-22 21:29:30.882815+00:00
# 4                 c             complete 2024-05-22 22:45:02.882815+00:00
# ...             ...                  ...                              ...
# 115249            f             complete 2024-05-23 00:24:18.342162+00:00
# 115250            j             complete 2024-05-23 00:50:38.342162+00:00
# 115251            f             complete 2024-05-23 02:07:02.342162+00:00
# 115252            f             complete 2024-05-23 03:30:02.342162+00:00
# 115253            d             complete 2024-05-23 04:18:57.342162+00:00
#
#        case:concept:name case:label
# 0                 case_0   positive
# 1                 case_0   positive
# 2                 case_0   positive
# 3                 case_0   positive
# 4                 case_0   positive
# ...                  ...        ...
# 115249         case_9999   positive
# 115250         case_9999   positive
# 115251         case_9999   positive
# 115252         case_9999   positive
# 115253         case_9999   positive
#
# [115254 rows x 5 columns]

# %%
# Deep copy log 
eventlog = df_log.copy(deep=True)

# Format case_id such that only integer value is shown
eventlog['case:concept:name'] = eventlog['case:concept:name'].str.replace('case_', '')
eventlog['case:concept:name'] = eventlog['case:concept:name'].astype(int)

# %%
eventlog
# Out:
#        concept:name lifecycle:transition                   time:timestamp
# 0                 a             complete 2024-05-22 18:04:19.882815+00:00  \
# 1                 c             complete 2024-05-22 19:14:47.882815+00:00
# 2                 c             complete 2024-05-22 19:57:48.882815+00:00
# 3                 c             complete 2024-05-22 21:29:30.882815+00:00
# 4                 c             complete 2024-05-22 22:45:02.882815+00:00
# ...             ...                  ...                              ...
# 115249            f             complete 2024-05-23 00:24:18.342162+00:00
# 115250            j             complete 2024-05-23 00:50:38.342162+00:00
# 115251            f             complete 2024-05-23 02:07:02.342162+00:00
# 115252            f             complete 2024-05-23 03:30:02.342162+00:00
# 115253            d             complete 2024-05-23 04:18:57.342162+00:00
#
#         case:concept:name case:label
# 0                       0   positive
# 1                       0   positive
# 2                       0   positive
# 3                       0   positive
# 4                       0   positive
# ...                   ...        ...
# 115249               9999   positive
# 115250               9999   positive
# 115251               9999   positive
# 115252               9999   positive
# 115253               9999   positive
#
# [115254 rows x 5 columns]

# %%
# Add column that indicates whether case is deviation or not
eventlog['deviation'] = np.where(eventlog['case:concept:name'].isin(deviations), 1, 0)
len(eventlog)
# test = eventlog[eventlog['deviation'] == 0] # df should be empty 
# test
# Out:
# 115254

# %%
# Delete traces without deviation ###################################
eventlog = eventlog[eventlog.deviation != 0]
len(eventlog)
# Out:
# 115223

# %%
# Add column that indicates whether case is anomaly or not (this is our label)
eventlog['anomaly'] = np.where(eventlog['case:concept:name'].isin(anomalies), 1, 0)

# test = eventlog[eventlog['anomaly'] == 1]
# test

print(anomalies)
# Out:
# [0, 6, 7, 8, 11, 12, 13, 14, 16, 19, 21, 22, 23, 24, 27, 29, 30, 31, 34, 35, 36, 38, 39, 41, 43, 46, 47, 48, 49, 51, 52, 53, 54, 55, 56, 57, 59, 60, 62, 63, 65, 68, 69, 70, 71, 72, 75, 76, 78, 79, 81, 82, 83, 84, 85, 86, 87, 88, 89, 90, 92, 93, 94, 95, 96, 99, 100, 101, 102, 103, 104, 105, 106, 107, 108, 109, 110, 111, 113, 114, 115, 116, 117, 118, 119, 120, 121, 123, 124, 125, 126, 127, 129, 133, 134, 135, 138, 139, 140, 141, 142, 143, 145, 146, 147, 148, 149, 150, 151, 153, 154, 156, 158, 159, 161, 162, 164, 165, 166, 167, 168, 170, 171, 172, 173, 175, 176, 177, 178, 179, 180, 181, 182, 183, 185, 186, 187, 188, 189, 190, 191, 192, 193, 195, 196, 197, 198, 199, 203, 204, 205, 206, 207, 212, 213, 214, 215, 218, 219, 220, 221, 222, 223, 224, 225, 226, 227, 228, 229, 230, 231, 232, 234, 235, 236, 237, 238, 239, 241, 242, 243, 244, 245, 248, 249, 250, 252, 253, 254, 255, 256, 257, 258, 259, 260, 261, 262, 263, 264, 265, 266, 267, 268, 269, 271, 272, 273, 274, 275, 276, 277, 278, 279, 282, 283, 284, 285, 286, 287, 288, 289, 290, 291, 293, 294, 296, 298, 299, 300, 301, 302, 303, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 322, 323, 324, 325, 326, 327, 328, 329, 330, 331, 332, 333, 334, 335, 336, 338, 341, 342, 344, 345, 346, 347, 349, 350, 351, 352, 353, 354, 355, 356, 357, 358, 359, 361, 362, 363, 364, 365, 366, 367, 368, 370, 371, 372, 373, 374, 375, 376, 378, 379, 380, 381, 383, 384, 386, 387, 388, 389, 390, 391, 392, 393, 394, 395, 396, 398, 399, 400, 401, 402, 403, 404, 405, 406, 407, 408, 409, 410, 411, 412, 414, 415, 416, 417, 418, 419, 420, 421, 422, 423, 424, 426, 427, 428, 429, 430, 432, 433, 434, 435, 436, 437, 438, 439, 441, 442, 443, 444, 445, 447, 448, 449, 450, 451, 452, 453, 454, 455, 456, 457, 458, 459, 460, 461, 462, 463, 464, 465, 466, 467, 469, 470, 471, 473, 474, 475, 476, 477, 478, 479, 481, 482, 483, 484, 485, 486, 487, 488, 489, 490, 491, 492, 493, 494, 495, 497, 498, 499, 500, 501, 502, 503, 504, 505, 506, 507, 508, 509, 510, 511, 512, 513, 514, 515, 516, 517, 518, 520, 521, 522, 523, 524, 526, 527, 528, 529, 530, 531, 532, 534, 535, 536, 537, 539, 541, 542, 543, 544, 545, 548, 549, 550, 551, 552, 553, 554, 555, 556, 557, 558, 559, 560, 561, 562, 563, 564, 565, 566, 567, 568, 570, 571, 572, 573, 574, 575, 576, 577, 578, 581, 582, 583, 584, 585, 586, 588, 589, 590, 591, 592, 593, 594, 595, 596, 597, 598, 601, 602, 603, 604, 605, 606, 607, 608, 609, 610, 611, 613, 614, 615, 616, 617, 618, 620, 621, 623, 624, 625, 626, 628, 629, 630, 631, 632, 633, 634, 635, 636, 637, 638, 639, 640, 641, 642, 643, 644, 645, 646, 647, 648, 649, 650, 651, 652, 653, 655, 656, 657, 658, 659, 660, 661, 663, 664, 666, 669, 670, 671, 672, 673, 674, 675, 677, 678, 679, 680, 681, 682, 683, 684, 685, 686, 687, 688, 689, 690, 691, 693, 694, 696, 697, 698, 701, 702, 703, 704, 707, 709, 711, 712, 713, 714, 715, 717, 718, 720, 722, 723, 724, 725, 726, 727, 729, 731, 732, 735, 736, 737, 738, 741, 743, 744, 745, 746, 747, 749, 751, 752, 753, 754, 755, 756, 758, 759, 760, 761, 762, 763, 764, 765, 766, 767, 768, 770, 771, 772, 773, 774, 775, 776, 777, 778, 780, 781, 782, 783, 784, 785, 786, 787, 788, 789, 790, 791, 792, 794, 795, 796, 797, 798, 800, 801, 802, 803, 804, 805, 806, 807, 808, 811, 812, 813, 814, 815, 816, 818, 819, 820, 821, 822, 823, 824, 825, 826, 827, 828, 829, 830, 831, 832, 833, 834, 835, 836, 837, 838, 839, 840, 841, 842, 843, 844, 845, 846, 848, 849, 850, 851, 852, 853, 854, 855, 856, 857, 858, 859, 860, 861, 862, 864, 865, 866, 867, 868, 869, 870, 871, 872, 874, 875, 877, 878, 879, 880, 881, 883, 884, 885, 886, 887, 889, 890, 891, 892, 893, 894, 895, 897, 898, 899, 901, 902, 903, 904, 905, 906, 907, 909, 910, 911, 913, 915, 916, 917, 918, 919, 920, 921, 922, 923, 924, 925, 926, 929, 930, 931, 932, 933, 934, 935, 937, 938, 939, 940, 941, 942, 944, 946, 947, 948, 949, 950, 952, 953, 954, 955, 956, 957, 958, 959, 961, 962, 963, 964, 965, 966, 967, 968, 970, 971, 972, 973, 974, 975, 976, ...
# C:\Users\lucp10256\AppData\Local\Temp\ipykernel_18588\693180818.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eventlog['anomaly'] = np.where(eventlog['case:concept:name'].isin(anomalies), 1, 0)

# %%
# Set input parameter: how many anomalies we want in the entire dataset
percent_anomalies = 0.1

# %%
# set number of anomalies and exceptions in entire dataset
num_anomalies = len(anomalies)
num_exceptions = len(exceptions)
num_deviations = num_anomalies + num_exceptions

# Check data imbalance
print("Number of anomalies: " + str(num_anomalies) + 
      "\nNumber of exceptions: " + str(num_exceptions))

adjusted_num_anomalies = round(percent_anomalies * num_exceptions)
adjusted_num_exceptions = num_exceptions - adjusted_num_anomalies
# Out:
# Number of anomalies: 8346
# Number of exceptions: 1651

# %%
print("Adjusted number of anomalies: " + str(len(adjusted_anomalies)))
print("Adjusted number of exceptions: " + str(len(adjusted_exceptions)))
# Out:
# Adjusted number of anomalies: 165
# Adjusted number of exceptions: 1486

# %%
# Get df with anomalies only
anomalies_df = eventlog[eventlog['anomaly']==1]
adjusted_anomalies = random.sample(sorted(anomalies), adjusted_num_anomalies)
anomalies_df['to_keep'] = np.where(anomalies_df['case:concept:name'].isin(adjusted_anomalies), 1, 0)

anomalies_df_new = anomalies_df[anomalies_df['to_keep']==1]
final_anomalies = anomalies_df_new.drop(['deviation', 'to_keep'],axis='columns')


# Balance data: reduce number of exceptions to equal number of anomalies
exceptions_df = eventlog[eventlog['anomaly']==0] 
adjusted_exceptions = random.sample(sorted(exceptions), adjusted_num_exceptions)
exceptions_df['to_keep'] = np.where(exceptions_df['case:concept:name'].isin(adjusted_exceptions), 1, 0)

exception_df_new = exceptions_df[exceptions_df['to_keep']==1]
final_exceptions = exception_df_new.drop(['deviation', 'to_keep'],axis='columns')
# Out:
# C:\Users\lucp10256\AppData\Local\Temp\ipykernel_18588\3557145348.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anomalies_df['to_keep'] = np.where(anomalies_df['case:concept:name'].isin(adjusted_anomalies), 1, 0)
# C:\Users\lucp10256\AppData\Local\Temp\ipykernel_18588\3557145348.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exceptions_df['to_keep'] = np.where(exceptions_df['case:concept:name'].isin(adjusted_exceptions), 1, 0)

# %%
# Get labeled deviation log 
labeled_deviations = pd.concat([final_anomalies,final_exceptions])
labeled_deviations

labeled_deviations.to_csv("M_labeled_deviations_TEST.csv")

# %% [markdown]
# 4 Transform event log to trace log

# %%
# import dataframe deviation log
# deviations = pd.read_csv("labeled_deviations_jupyter_imbalanced.csv")
deviations = labeled_deviations

# convert 'time:timestamp' to datetime
deviations['time:timestamp'] = pd.to_datetime(deviations['time:timestamp'],format="ISO8601")
deviations_sorted = deviations.groupby('case:concept:name').apply(lambda x: x.sort_values('time:timestamp')).reset_index(drop=True)

deviations_sorted
# Out:
#       concept:name lifecycle:transition                   time:timestamp
# 0                h             complete 2024-05-22 18:02:45.882815+00:00  \
# 1                j             complete 2024-05-22 19:15:46.882815+00:00
# 2                c             complete 2024-05-22 20:15:21.882815+00:00
# 3                a             complete 2024-05-22 21:08:46.882815+00:00
# 4                a             complete 2024-05-22 21:47:00.882815+00:00
# ...            ...                  ...                              ...
# 18177            j             complete 2024-05-22 23:55:22.342162+00:00
# 18178            b             complete 2024-05-23 01:13:07.342162+00:00
# 18179            j             complete 2024-05-23 01:53:46.342162+00:00
# 18180            f             complete 2024-05-23 03:01:28.342162+00:00
# 18181            d             complete 2024-05-23 04:42:55.342162+00:00
#
#        case:concept:name case:label  anomaly
# 0                      1   positive        0
# 1                      1   positive        0
# 2                      1   positive        0
# 3                      1   positive        0
# 4                      1   positive        0
# ...                  ...        ...      ...
# 18177               9992   positive        0
# 18178               9992   positive        0
# 18179               9992   positive        0
# 18180               9992   positive        0
# 18181               9992   positive        0
#
# [18182 rows x 6 columns]

# %%
# transform event log to trace log
traces = deviations_sorted.groupby('case:concept:name').agg({
    'concept:name': lambda x: f"<{', '.join(x)}>",
    'anomaly': 'first'
    }).reset_index()
traces.columns = ['case:concept:name', 'trace', 'label']

traces
# Out:
#       case:concept:name                              trace  label
# 0                     1     <h, j, c, a, a, c, d, j, f, d>      0
# 1                     2     <h, c, c, c, j, b, a, c, f, d>      0
# 2                     3     <h, c, j, a, c, b, e, j, f, d>      0
# 3                     4     <j, h, g, a, c, a, b, b, f, d>      0
# 4                     5     <a, h, b, g, c, a, a, j, f, d>      0
# ...                 ...                                ...    ...
# 1646               9959  <h, j, h, f, g, f, f, b, f, f, d>      1
# 1647               9964  <c, j, f, h, b, j, j, h, i, f, d>      0
# 1648               9984  <j, d, f, h, b, d, j, b, j, f, d>      0
# 1649               9991  <h, j, h, f, f, f, f, c, f, f, d>      1
# 1650               9992  <j, d, f, i, h, d, j, b, j, f, d>      0
#
# [1651 rows x 3 columns]

# %%
# merge trace log and results conformance checking
# merged_norm = pd.merge(left=traces, right=df_norm, how="left", left_on="case:concept:name", right_index=True)
merged_audit = pd.merge(left=traces, right=df_audit, how="left", left_on="case:concept:name", right_index=True)

# %%
merged_audit.sample(20)
# Out:
#       case:concept:name                                       trace  label
# 1478               8397  <c, d, d, a, a, a, a, d, d, a, d, d, e, d>      0  \
# 504                2492                 <a, h, c, j, c, a, b, f, d>      0
# 442                2226                    <j, f, d, f, d, h, d, d>      1
# 346                1834                    <h, c, c, j, d, d, f, d>      0
# 43                  163              <a, a, h, h, c, j, f, j, d, d>      0
# 1337               7087     <h, d, j, f, d, d, j, d, d, d, d, f, d>      0
# 605                2765                 <j, j, j, j, h, f, d, c, d>      0
# 34                  112              <c, j, h, h, d, d, d, d, f, d>      0
# 600                2726                 <h, b, h, h, d, j, f, d, d>      0
# 478                2373                    <h, j, f, d, i, d, b, d>      0
# 694                3151                 <h, c, j, d, a, h, i, f, d>      0
# 612                2791                 <h, j, c, d, d, h, f, b, d>      0
# 1593               9388           <j, d, f, j, h, d, h, b, j, f, d>      0
# 1365               7340     <j, i, h, i, d, c, j, i, f, a, c, e, d>      0
# 1354               7268     <j, i, h, i, d, g, c, i, f, a, i, e, d>      0
# 1606               9500           <j, d, f, d, h, b, h, b, j, f, d>      0
# 349                1851                    <d, d, d, d, j, f, c, d>      0
# 1411               7628  <h, j, h, d, h, d, h, i, d, j, d, f, d, d>      0
# 714                3277                 <h, c, d, d, j, a, a, f, d>      0
# 706                3234                 <j, h, j, b, h, f, d, c, d>      0
#
#       Unnamed: 0  End[d] | | |  Response[h, f] | | |  Precedence[h, b] | | |
# 1478        8397             1                     1                       1  \
# 504         2492             1                     1                       1
# 442         2226             1                     0                       1
# 346         1834             1                     1                       1
# 43           163             1                     1                       1
# 1337        7087             1                     1                       1
# 605         2765             1                     1                       1
# 34           112             1                     1                       1
# 600         2726             1                     1                       1
# 478         2373             1                     1                       1
# 694         3151             1                     1                       1
# 612         2791             1                     1                       1
# 1593        9388             1                     1                       1
# 1365        7340             1                     1                       1
# 1354        7268             1                     1                       1
# 1606        9500             1                     1                       1
# 349         1851             1                     1                       1
# 1411        7628             1                     1                       1
# 714         3277             1                     1                       1
# 706         3234             1                     1                       1
#
#       Responded Existence[j, f] | | |  Alternate Precedence[j, f] | | |
# 1478                                1                                 1  \
# 504                                 1                                 1
# 442                                 1                                 0
# 346                                 1                                 1
# 43                                  1                                 1
# 1337                                1                                 1
# 605                                 1                                 1
# 34                                  1                                 1
# 600                                 1                                 1
# 478                                 1                                 1
# 694                                 1                                 1
# 612                                 1                                 1
# 1593                                1                                 1
# 1365                                1                                 1
# 1354                                1                                 1
# 1606                                1                                 1
# 349                                 1                                 1
# 1411                                1                                 1
# 714                                 1                                 1
# 706                                 1                                 1
#
#       Responded Existence[a, c] | | |  Precedence[a, e] | | |
# 1478                                1                       1  \
# 504                                 1                       1
# 442                                 1                       1
# 346                                 1                       1
# 43                                  1                       1
# 1337                                1                       1
# 605                                 1                       1
# 34                                  1                       1
# 600                                 1                       1
# 478                                 1                       1
# 694                                 1                       1
# 612                                 1                       1
# 1593                                1                       1
# 1365                                1                       1
# 1354                                1                       1
# 1606                                1                       1
# 349                                 1                       1
# 1411                                1                       1
# 714                                 1                       1
# 706                                 1                       1
#
#       Responded Existence[g, c] | | |
# 1478                                1
# 504                                 1
# 442                                 1
# 346                                 1
# 43                                  1
# 1337                                1
# 605                                 1
# 34                                  1
# 600                                 1
# 478                                 1
# 694                                 1
# 612                                 1
# 1593                                1
# 1365                                1
# 1354                                1
# 1606                                1
# 349                                 1
# 1411                                1
# 714                                 1
# 706                                 1

# %%
# export files 
# merged_norm.to_csv("M_TEST_results_normative_imbalanced.csv", index=False)  
merged_audit.to_csv("M_results_TEST__.csv", index=False)

# %% [markdown]
# 5 Apply Machine Learning technique to classify deviating traces as anomaly (1) or exception (0)

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier 
from sklearn.model_selection import train_test_split
from sklearn import metrics
# Out:
# DEBUG:matplotlib:CACHEDIR=C:\Users\lucp10256\.matplotlib
# DEBUG:matplotlib.font_manager:Using fontManager instance from C:\Users\lucp10256\.matplotlib\fontlist-v330.json

# %%
data = merged_audit

# %%
# get index of 'label' column
label_index = data.columns.get_loc('label')

# select all columns after 'label' column
features = data.iloc[:, label_index + 1:]

# split dataset in features and target variable
X = features 
y = data['label'] 

# split dataset in training and test set
train_test_perc = 0.3
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=train_test_perc)

# %%
# apply Decision Tree Classifier
clf = DecisionTreeClassifier()
clf = clf.fit(X_train,y_train)
y_pred = clf.predict(X_test)

# apply Decision Tree Classifier
clf = DecisionTreeClassifier()
clf = clf.fit(X_train,y_train)
y_pred = clf.predict(X_test)

# %%
# metrics
accuracy = metrics.accuracy_score(y_test, y_pred)
precision = metrics.precision_score(y_test, y_pred)
recall = metrics.recall_score(y_test, y_pred)
f1_score = metrics.f1_score(y_test, y_pred)
auc_score = metrics.roc_auc_score(y_test, y_pred)

print('Accuracy: ', accuracy)
print('Precision: ', precision)
print('Recall: ', recall)
print('F1-score: ', f1_score)
print('AUC-score: ', auc_score)
# Out:
# Accuracy:  0.9959677419354839
# Precision:  1.0
# Recall:  0.9629629629629629
# F1-score:  0.9811320754716981
# AUC-score:  0.9814814814814814

# %% [markdown]
# 6 Save results

# %%
import time
import csv

# %%
# Files
time_file = time.time()

result = {
    "num_constraints": [],
    "num_activities": [],
    "len_training_set": [],
    "len_test_set":[],
    "train_test_perc":[],
    "num_labeled_deviations":[],
    "perc_anomalies": [],
    "classifier":[],
    "precision": [],
    "recall": [],
    "F1_score": [],
    "accuracy": [],
    "AUC_score": [],
}
df1 = pd.DataFrame(result)
df1.to_csv("TEST_result_{0}.csv".format(time_file), sep=',',index=False)

# %%
# def save_results(filename):
#     file = open(filename, 'w',  encoding="utf-8") # overwrite if file already exists
#     output = Model.constraintlist.list_to_decl_extension(constraint_list, activities)
#     file.write(str(output))
#     file.close()

# %%
num_constraints = 0
num_activities = 0
len_training = len(y_train)
len_test = len(y_test)
num_labeled_deviations = len_training + len_test
classifier = "DT"

# %%
fields1 = [num_constraints, 
            num_activities, 
            len_training, 
            len_test,
            train_test_perc, 
            num_labeled_deviations, 
            percent_anomalies,
            classifier, 
            precision, 
            recall,
            f1_score,
            accuracy,
            auc_score]

with open(r"TEST_result_{0}.csv".format(time_file), 'a') as f:
    writer = csv.writer(f)
    writer.writerow(fields1)
